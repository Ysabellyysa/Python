# %% [markdown]
# <a href="https://colab.research.google.com/github/Ysabellyysa/Python/blob/main/Activation_and_loss_Functions_Aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

#(1/(1+e(-x)))
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %% [markdown]
# ## ReLU

# %%
import torch

class ReLU(torch.nn.Module):
  def __init__(self):
    super().__init__()

  def forward(self, x):
    return torch.max(torch.zeros_like)

# %% [markdown]
# ### Loss Functions
# #### Mean-squared error

# %%
import numpy as np
def mse_loss(y_true, y_pred):
  return np.mean((y_true - y_pred)**2)

# %% [markdown]
# ### Cross entropy Loss
# #### L = -(1/N) * sum(y_true*log(y_pred)+(1-y_true)*log(1-y_pred))

# %%
import numpy as np

def cross_entropy_loss(y_true, y_pres):
  epsilon = 1e-15
  y_pred = np.clip(y_pred, epsilon, 1 - epsilon) # To avoid zero division
  return -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))
