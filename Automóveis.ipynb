# %% [markdown]
# <a href="https://colab.research.google.com/github/Ysabellyysa/Python/blob/main/Autom%C3%B3veis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.1)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.4.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import utils as np_utils
from tensorflow.keras import backend as k
from tensorflow.keras.models import Sequential
from sklearn.model_selection import cross_val_score

# %%
# Importando as bibliotecas que serão utilizadas
import pandas as pd
import tensorflow as tf      # Deep Learning
import sklearn               # Machine Learnin

# %%
base = pd.read_csv('autos.csv' , encoding = 'ISO-8859-1')
base
# Out:
#                 dateCrawled  \
# 0       2016-03-24 11:52:17
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# ...                     ...
# 125188  2016-03-19 18:52:38
# 125189  2016-03-28 20:50:53
# 125190  2016-03-20 00:57:46
# 125191  2016-03-25 15:56:09
# 125192  2016-03-18 18:42:58
#
#                                                      name  seller offerType  \
# 0                                              Golf_3_1.6  privat   Angebot
# 1                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 2                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# ...                                                   ...     ...       ...
# 125188  SEAT_Ibiza_1.4L_16V_Bj.2003_TÜV8/16_silber_TÜV...  privat   Angebot
# 125189                           Octavia_Avant_2.0_TDI_RS  privat   Angebot
# 125190    Volkswagen_Passat_Variant_2.0_TDI_DPF_Sportline  privat   Angebot
# 125191              Volkswagen_Passat_Variant_2.0_Pacific  privat   Angebot
# 125192            biete_hier_einen_ford_fiesta_baujahr_95  privat    Angebo
#
#           price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480.0     test         NaN              1993.0    manuell      0.0
# 1       18300.0     test       coupe              2011.0    manuell    190.0
# 2        9800.0     test         suv              2004.0  automatik    163.0
# 3        1500.0     test  kleinwagen              2001.0    manuell     75.0
# 4        3600.0     test  kleinwagen              2008.0    manuell     69.0
# ...         ...      ...         ...                 ...        ...      ...
# 125188   3200.0     test  kleinwagen              2003.0    manuell     75.0
# 125189   2990.0  control       kombi              2008.0        NaN      0.0
# 125190   9250.0  control       kombi              2008.0    manuell    170.0
# 125191    650.0     test       kombi              1996.0    manuell    116.0
# 125192      NaN      NaN         NaN                 NaN        NaN      NaN
#
#           model  kilometer  monthOfRegistration fuelType       brand  \
# 0          golf   150000.0                  0.0   benzin  volkswagen
# 1           NaN   125000.0                  5.0   diesel        audi
# 2         grand   125000.0                  8.0   diesel        jeep
# 3          golf   150000.0                  6.0   benzin  volkswagen
# 4         fabia    90000.0                  7.0   diesel       skoda
# ...         ...        ...                  ...      ...         ...
# 125188    ibiza   150000.0                  8.0   benzin        seat
# 125189  octavia   150000.0                 10.0   diesel       skoda
# 125190   passat   150000.0                  5.0   diesel  volkswagen
# 125191   passat   150000.0                 12.0   benzin  volkswagen
# 125192      NaN        NaN                  NaN      NaN         NaN
#
#        notRepairedDamage          dateCreated  nrOfPictures  postalCode  \
# 0                    NaN  2016-03-24 00:00:00           0.0     70435.0
# 1                     ja  2016-03-24 00:00:00           0.0     66954.0
# 2                    NaN  2016-03-14 00:00:00           0.0     90480.0
# 3                   nein  2016-03-17 00:00:00           0.0     91074.0
# 4                   nein  2016-03-31 00:00:00           0.0     60437.0
# ...                  ...                  ...           ...         ...
# 125188              nein  2016-03-19 00:00:00           0.0     40880.0
# 125189              nein  2016-03-28 00:00:00           0.0     50737.0
# 125190              nein  2016-03-19 00:00:00           0.0     90489.0
# 125191              nein  2016-03-25 00:00:00           0.0     49828.0
# 125192               NaN                  NaN           NaN         NaN
#
#                    lastSeen
# 0       2016-04-07 03:16:57
# 1       2016-04-07 01:46:50
# 2       2016-04-05 12:47:46
# 3       2016-03-17 17:40:17
# 4       2016-04-06 10:17:21
# ...                     ...
# 125188  2016-04-07 06:16:40
# 125189  2016-03-28 20:50:53
# 125190  2016-04-06 03:16:26
# 125191  2016-04-06 20:16:56
# 125192                  NaN
#
# [125193 rows x 20 columns]

# %%
# Remoção dos atributos que não irão influenciar em prever o preço
base = base.drop('dateCrawled', axis = 1)
base = base.drop('dateCreated', axis = 1)
base = base.drop('nrOfPictures', axis = 1)
base = base.drop('postalCode', axis = 1)
base = base.drop('lastSeen', axis = 1)
base
# Out:
#                                                      name  seller offerType  \
# 0                                              Golf_3_1.6  privat   Angebot
# 1                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 2                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# ...                                                   ...     ...       ...
# 125188  SEAT_Ibiza_1.4L_16V_Bj.2003_TÜV8/16_silber_TÜV...  privat   Angebot
# 125189                           Octavia_Avant_2.0_TDI_RS  privat   Angebot
# 125190    Volkswagen_Passat_Variant_2.0_TDI_DPF_Sportline  privat   Angebot
# 125191              Volkswagen_Passat_Variant_2.0_Pacific  privat   Angebot
# 125192            biete_hier_einen_ford_fiesta_baujahr_95  privat    Angebo
#
#           price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480.0     test         NaN              1993.0    manuell      0.0
# 1       18300.0     test       coupe              2011.0    manuell    190.0
# 2        9800.0     test         suv              2004.0  automatik    163.0
# 3        1500.0     test  kleinwagen              2001.0    manuell     75.0
# 4        3600.0     test  kleinwagen              2008.0    manuell     69.0
# ...         ...      ...         ...                 ...        ...      ...
# 125188   3200.0     test  kleinwagen              2003.0    manuell     75.0
# 125189   2990.0  control       kombi              2008.0        NaN      0.0
# 125190   9250.0  control       kombi              2008.0    manuell    170.0
# 125191    650.0     test       kombi              1996.0    manuell    116.0
# 125192      NaN      NaN         NaN                 NaN        NaN      NaN
#
#           model  kilometer  monthOfRegistration fuelType       brand  \
# 0          golf   150000.0                  0.0   benzin  volkswagen
# 1           NaN   125000.0                  5.0   diesel        audi
# 2         grand   125000.0                  8.0   diesel        jeep
# 3          golf   150000.0                  6.0   benzin  volkswagen
# 4         fabia    90000.0                  7.0   diesel       skoda
# ...         ...        ...                  ...      ...         ...
# 125188    ibiza   150000.0                  8.0   benzin        seat
# 125189  octavia   150000.0                 10.0   diesel       skoda
# 125190   passat   150000.0                  5.0   diesel  volkswagen
# 125191   passat   150000.0                 12.0   benzin  volkswagen
# 125192      NaN        NaN                  NaN      NaN         NaN
#
#        notRepairedDamage
# 0                    NaN
# 1                     ja
# 2                    NaN
# 3                   nein
# 4                   nein
# ...                  ...
# 125188              nein
# 125189              nein
# 125190              nein
# 125191              nein
# 125192               NaN
#
# [125193 rows x 15 columns]

# %%
base['name'].value_counts()
# Out:
# name
# Ford_Fiesta                                                        232
# Volkswagen_Golf_1.4                                                225
# BMW_318i                                                           214
# Opel_Corsa                                                         199
# BMW_316i                                                           190
#                                                                   ...
# Volkswagen_Polo_1.4_Comfortline_1_Hand_scheckheftgepflegt            1
# Mercedes_Benz_200E_W124_1Hd__135tkm_original                         1
# Opel_Kadett_C_City__Scheunenfund__abgemeldet_seit_1993               1
# Mercedes_Benz_E_250_T_CGI_BlueEFFICIENCY_Automatik_Elegance          1
# Mercedes_230TE_Automatik_Defekt_oder_Tausch_GE_Handy_TVs_Laptop      1
# Name: count, Length: 88674, dtype: int64

# %%
# removendo a coluna name pq ela possui valores unicos
base = base.drop('name', axis = 1)

# %%
base['seller'].value_counts()
# Out:
# seller
# privat        125192
# gewerblich         1
# Name: count, dtype: int64

# %%
base = base.drop('seller', axis = 1)

# %%
base['offerType'].value_counts()
# Out:
# offerType
# Angebot    125190
# Gesuch          2
# Angebo          1
# Name: count, dtype: int64

# %%
base = base.drop('offerType', axis = 1)

# %%
base
# Out:
#           price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480.0     test         NaN              1993.0    manuell      0.0
# 1       18300.0     test       coupe              2011.0    manuell    190.0
# 2        9800.0     test         suv              2004.0  automatik    163.0
# 3        1500.0     test  kleinwagen              2001.0    manuell     75.0
# 4        3600.0     test  kleinwagen              2008.0    manuell     69.0
# ...         ...      ...         ...                 ...        ...      ...
# 125188   3200.0     test  kleinwagen              2003.0    manuell     75.0
# 125189   2990.0  control       kombi              2008.0        NaN      0.0
# 125190   9250.0  control       kombi              2008.0    manuell    170.0
# 125191    650.0     test       kombi              1996.0    manuell    116.0
# 125192      NaN      NaN         NaN                 NaN        NaN      NaN
#
#           model  kilometer  monthOfRegistration fuelType       brand  \
# 0          golf   150000.0                  0.0   benzin  volkswagen
# 1           NaN   125000.0                  5.0   diesel        audi
# 2         grand   125000.0                  8.0   diesel        jeep
# 3          golf   150000.0                  6.0   benzin  volkswagen
# 4         fabia    90000.0                  7.0   diesel       skoda
# ...         ...        ...                  ...      ...         ...
# 125188    ibiza   150000.0                  8.0   benzin        seat
# 125189  octavia   150000.0                 10.0   diesel       skoda
# 125190   passat   150000.0                  5.0   diesel  volkswagen
# 125191   passat   150000.0                 12.0   benzin  volkswagen
# 125192      NaN        NaN                  NaN      NaN         NaN
#
#        notRepairedDamage
# 0                    NaN
# 1                     ja
# 2                    NaN
# 3                   nein
# 4                   nein
# ...                  ...
# 125188              nein
# 125189              nein
# 125190              nein
# 125191              nein
# 125192               NaN
#
# [125193 rows x 12 columns]

# %%
base.loc[base['price'] <= 10]
# Out:
#         price   abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 7         0.0     test   limousine              1980.0  manuell     50.0
# 40        0.0     test         NaN              1990.0      NaN      0.0
# 60        1.0  control         suv              1994.0  manuell    286.0
# 91        1.0  control   limousine              1995.0  manuell    113.0
# 115       0.0     test         NaN              2017.0  manuell      0.0
# ...       ...      ...         ...                 ...      ...      ...
# 125125    0.0  control         NaN              2000.0      NaN      0.0
# 125127    0.0  control       kombi              2008.0  manuell    140.0
# 125151    0.0  control  kleinwagen              2003.0  manuell     60.0
# 125159    0.0  control       kombi              1996.0      NaN      0.0
# 125170    0.0     test         NaN              1980.0      NaN      0.0
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 7         andere    40000.0                  7.0   benzin      volkswagen
# 40         corsa   150000.0                  1.0   benzin            opel
# 60           NaN   150000.0                 11.0      NaN  sonstige_autos
# 91      e_klasse   150000.0                  4.0   diesel   mercedes_benz
# 115         golf     5000.0                 12.0   benzin      volkswagen
# ...          ...        ...                  ...      ...             ...
# 125125       NaN     5000.0                  0.0      NaN           mazda
# 125127     astra    90000.0                  0.0   benzin            opel
# 125151        ka   125000.0                  2.0   benzin            ford
# 125159       NaN     5000.0                  0.0      NaN      volkswagen
# 125170    andere    60000.0                  0.0      NaN       chevrolet
#
#        notRepairedDamage
# 7                   nein
# 40                   NaN
# 60                   NaN
# 91                  nein
# 115                  NaN
# ...                  ...
# 125125               NaN
# 125127              nein
# 125151                ja
# 125159               NaN
# 125170              nein
#
# [4108 rows x 12 columns]

# %%
base['price'].mean()
# Out:
# np.float64(10741.025209278549)

# %%
base.shape
# Out:
# (125193, 12)

# %%
base.loc[base['price'] > 350000]
# Out:
#              price   abtest vehicleType  yearOfRegistration    gearbox  \
# 1846      579000.0  control       coupe              1980.0    manuell
# 10649     420000.0  control       coupe              2004.0    manuell
# 14663   11111111.0  control       coupe              2003.0    manuell
# 16889    1000000.0  control       kombi              1998.0        NaN
# 20143    1250000.0     test       coupe              2016.0    manuell
# 20746   12345678.0     test         NaN              1995.0        NaN
# 21467    9999999.0  control       coupe              1967.0    manuell
# 26327     600000.0     test       coupe              2016.0    manuell
# 38445     999999.0     test         bus              1981.0    manuell
# 39625   12345678.0  control         NaN              2018.0    manuell
# 41980    2995000.0  control       coupe              2005.0        NaN
# 45055    2795000.0  control       coupe              2016.0        NaN
# 45833    1000000.0  control       coupe              1981.0    manuell
# 53507    1000000.0     test         suv              1992.0    manuell
# 54295   10000000.0  control         bus              2007.0    manuell
# 54507   11111111.0     test      andere              1953.0    manuell
# 56973   99999999.0  control   limousine              2002.0    manuell
# 57594    1111111.0     test         NaN              1995.0    manuell
# 69726     999999.0     test      andere              1960.0    manuell
# 69747   99999999.0  control         bus              2006.0        NaN
# 77185     500000.0     test       coupe              2004.0    manuell
# 77520   99999999.0  control   limousine              1999.0  automatik
# 78265     820000.0  control      cabrio              2016.0        NaN
# 78480    1250000.0     test       coupe              2016.0    manuell
# 82700     395000.0     test      cabrio              1972.0    manuell
# 85047     911911.0     test      cabrio              1967.0    manuell
# 87799   27322222.0  control   limousine              2014.0    manuell
# 90853   11111111.0  control         NaN              2018.0        NaN
# 91106    9999999.0     test   limousine              1996.0    manuell
# 100851    700000.0     test       coupe              2016.0        NaN
# 106651   1111111.0  control         NaN              2000.0        NaN
# 108987  99999999.0     test         NaN              2017.0    manuell
# 111647    725000.0     test       coupe              1971.0    manuell
# 118058    517895.0     test       kombi              2013.0  automatik
# 118143    745000.0     test       coupe              2016.0    manuell
# 118233    999999.0     test         suv              1998.0  automatik
# 119382    500000.0     test       coupe              2016.0    manuell
# 120919  74185296.0     test         NaN              2000.0        NaN
# 121793  10000000.0  control         NaN              1910.0        NaN
#
#         powerPS        model  kilometer  monthOfRegistration fuelType  \
# 1846      277.0       andere    20000.0                 12.0   benzin
# 10649     483.0          911    50000.0                  4.0   benzin
# 14663      64.0         polo   150000.0                  2.0   benzin
# 16889       0.0       mondeo   150000.0                  0.0   benzin
# 20143     500.0          911     5000.0                  3.0   benzin
# 20746       0.0          NaN   150000.0                  0.0      NaN
# 21467     215.0          911    50000.0                 10.0   benzin
# 26327     500.0          911     5000.0                  3.0   benzin
# 38445      70.0  transporter   150000.0                  1.0   benzin
# 39625      95.0          v40   150000.0                  6.0      NaN
# 41980     630.0          NaN     5000.0                  7.0   benzin
# 45055     963.0          NaN     5000.0                  3.0      NaN
# 45833     300.0          911   150000.0                  1.0   benzin
# 53507      69.0       andere   100000.0                  0.0   benzin
# 54295     143.0      5_reihe   150000.0                  2.0   diesel
# 54507      20.0          NaN   150000.0                  5.0      NaN
# 56973     131.0       mondeo   150000.0                  1.0      NaN
# 57594      71.0        astra   150000.0                  5.0   benzin
# 69726    9999.0          NaN   150000.0                  0.0      NaN
# 69747       0.0       andere   150000.0                  0.0   diesel
# 77185     435.0          NaN    30000.0                  7.0   benzin
# 77520     224.0     s_klasse   150000.0                  9.0   benzin
# 78265     674.0          NaN     5000.0                  3.0   benzin
# 78480     500.0          911     5000.0                  3.0   benzin
# 82700     194.0          NaN   100000.0                  1.0   benzin
# 85047     160.0          911     5000.0                 12.0   benzin
# 87799     163.0           c4    40000.0                  2.0   diesel
# 90853       0.0          NaN   150000.0                  0.0      NaN
# 91106     380.0           a4    60000.0                  5.0   benzin
# 100851      0.0          911     5000.0                  3.0      NaN
# 106651      0.0          NaN   150000.0                  0.0      NaN
# 108987    110.0         golf   150000.0                  0.0      NaN
# 111647    625.0          NaN     5000.0                  4.0   benzin
# 118058    245.0       andere    40000.0                  1.0   diesel
# 118143    500.0          911     5000.0                  3.0   benzin
# 118233    241.0        grand   150000.0                  1.0   benzin
# 119382    500.0          911     5000.0                  2.0   benzin
# 120919      0.0          145    20000.0                  0.0      NaN
# 121793      0.0       kaefer   100000.0                  0.0      NaN
#
#                  brand notRepairedDamage
# 1846               bmw              nein
# 10649          porsche              nein
# 14663       volkswagen               NaN
# 16889             ford                ja
# 20143          porsche              nein
# 20746       volkswagen               NaN
# 21467          porsche              nein
# 26327          porsche              nein
# 38445       volkswagen               NaN
# 39625            volvo              nein
# 41980   sonstige_autos              nein
# 45055   sonstige_autos              nein
# 45833          porsche              nein
# 53507           suzuki              nein
# 54295            mazda              nein
# 54507             audi              nein
# 56973             ford               NaN
# 57594             opel               NaN
# 69726    mercedes_benz               NaN
# 69747    mercedes_benz               NaN
# 77185   sonstige_autos              nein
# 77520    mercedes_benz               NaN
# 78265   sonstige_autos              nein
# 78480          porsche              nein
# 82700   sonstige_autos              nein
# 85047          porsche              nein
# 87799          citroen               NaN
# 90853              bmw               NaN
# 91106             audi              nein
# 100851         porsche              nein
# 106651  sonstige_autos              nein
# 108987      volkswagen               NaN
# 111647  sonstige_autos              nein
# 118058            audi              nein
# 118143         porsche              nein
# 118233            jeep              nein
# 119382         porsche              nein
# 120919      alfa_romeo               NaN
# 121793      volkswagen               NaN

# %%
base.shape
# Out:
# (125193, 12)

# %%
base.loc[pd.isnull(base['vehicleType'])]
# Out:
#           price   abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 0         480.0     test         NaN              1993.0  manuell      0.0
# 16        300.0     test         NaN              2016.0      NaN     60.0
# 22       2900.0     test         NaN              2018.0  manuell     90.0
# 26       5555.0  control         NaN              2017.0  manuell    125.0
# 31        899.0  control         NaN              2016.0  manuell     60.0
# ...         ...      ...         ...                 ...      ...      ...
# 125131    300.0  control         NaN              2017.0      NaN      0.0
# 125144    999.0     test         NaN              2017.0  manuell    101.0
# 125154  31499.0     test         NaN              2018.0  manuell    300.0
# 125170      0.0     test         NaN              1980.0      NaN      0.0
# 125192      NaN      NaN         NaN                 NaN      NaN      NaN
#
#          model  kilometer  monthOfRegistration fuelType       brand  \
# 0         golf   150000.0                  0.0   benzin  volkswagen
# 16        polo   150000.0                  0.0   benzin  volkswagen
# 22      meriva   150000.0                  5.0   benzin        opel
# 26          c4   125000.0                  4.0      NaN     citroen
# 31        clio   150000.0                  6.0   benzin     renault
# ...        ...        ...                  ...      ...         ...
# 125131   focus   150000.0                  0.0      NaN        ford
# 125144      a3   150000.0                  4.0   benzin        audi
# 125154    golf    20000.0                  3.0      NaN  volkswagen
# 125170  andere    60000.0                  0.0      NaN   chevrolet
# 125192     NaN        NaN                  NaN      NaN         NaN
#
#        notRepairedDamage
# 0                    NaN
# 16                   NaN
# 22                  nein
# 26                  nein
# 31                   NaN
# ...                  ...
# 125131                ja
# 125144               NaN
# 125154              nein
# 125170              nein
# 125192               NaN
#
# [12637 rows x 12 columns]

# %%
base['vehicleType'].mode()
# Out:
# 0    limousine
# Name: vehicleType, dtype: object

# %%
base.loc[pd.isnull(base['gearbox'])]
# Out:
#          price   abtest vehicleType  yearOfRegistration gearbox  powerPS  \
# 15       450.0     test  kleinwagen              1910.0     NaN      0.0
# 16       300.0     test         NaN              2016.0     NaN     60.0
# 32       245.0     test   limousine              1994.0     NaN      0.0
# 37      1500.0     test         NaN              2016.0     NaN      0.0
# 40         0.0     test         NaN              1990.0     NaN      0.0
# ...        ...      ...         ...                 ...     ...      ...
# 125131   300.0  control         NaN              2017.0     NaN      0.0
# 125159     0.0  control       kombi              1996.0     NaN      0.0
# 125170     0.0     test         NaN              1980.0     NaN      0.0
# 125189  2990.0  control       kombi              2008.0     NaN      0.0
# 125192     NaN      NaN         NaN                 NaN     NaN      NaN
#
#           model  kilometer  monthOfRegistration fuelType       brand  \
# 15           ka     5000.0                  0.0   benzin        ford
# 16         polo   150000.0                  0.0   benzin  volkswagen
# 32         golf   150000.0                  2.0   benzin  volkswagen
# 37       kangoo   150000.0                  1.0   diesel     renault
# 40        corsa   150000.0                  1.0   benzin        opel
# ...         ...        ...                  ...      ...         ...
# 125131    focus   150000.0                  0.0      NaN        ford
# 125159      NaN     5000.0                  0.0      NaN  volkswagen
# 125170   andere    60000.0                  0.0      NaN   chevrolet
# 125189  octavia   150000.0                 10.0   diesel       skoda
# 125192      NaN        NaN                  NaN      NaN         NaN
#
#        notRepairedDamage
# 15                   NaN
# 16                   NaN
# 32                  nein
# 37                  nein
# 40                   NaN
# ...                  ...
# 125131                ja
# 125159               NaN
# 125170              nein
# 125189              nein
# 125192               NaN
#
# [6793 rows x 12 columns]

# %%
base['gearbox'].value_counts()
# Out:
# gearbox
# manuell      92585
# automatik    25815
# Name: count, dtype: int64

# %%
base.loc[pd.isnull(base['model'])]
# Out:
#           price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 1       18300.0     test       coupe              2011.0    manuell    190.0
# 60          1.0  control         suv              1994.0    manuell    286.0
# 83        350.0  control  kleinwagen              1997.0    manuell     54.0
# 119         0.0     test  kleinwagen              1999.0        NaN      0.0
# 139      1450.0  control   limousine              1992.0    manuell    136.0
# ...         ...      ...         ...                 ...        ...      ...
# 125125      0.0  control         NaN              2000.0        NaN      0.0
# 125147   2599.0     test   limousine              1979.0  automatik    116.0
# 125159      0.0  control       kombi              1996.0        NaN      0.0
# 125164   1800.0     test  kleinwagen              1964.0    manuell      0.0
# 125192      NaN      NaN         NaN                 NaN        NaN      NaN
#
#        model  kilometer  monthOfRegistration fuelType           brand  \
# 1        NaN   125000.0                  5.0   diesel            audi
# 60       NaN   150000.0                 11.0      NaN  sonstige_autos
# 83       NaN   150000.0                  3.0      NaN            fiat
# 119      NaN     5000.0                  0.0   benzin      volkswagen
# 139      NaN   150000.0                  0.0      NaN            audi
# ...      ...        ...                  ...      ...             ...
# 125125   NaN     5000.0                  0.0      NaN           mazda
# 125147   NaN   125000.0                  9.0   benzin            opel
# 125159   NaN     5000.0                  0.0      NaN      volkswagen
# 125164   NaN   150000.0                  2.0   benzin            audi
# 125192   NaN        NaN                  NaN      NaN             NaN
#
#        notRepairedDamage
# 1                     ja
# 60                   NaN
# 83                    ja
# 119                  NaN
# 139                 nein
# ...                  ...
# 125125               NaN
# 125147              nein
# 125159               NaN
# 125164               NaN
# 125192               NaN
#
# [6895 rows x 12 columns]

# %%
base.loc[pd.isnull(base['fuelType'])]
# Out:
#           price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 9         999.0     test  kleinwagen              1998.0    manuell    101.0
# 13       2500.0  control       kombi              2004.0    manuell    131.0
# 26       5555.0  control         NaN              2017.0    manuell    125.0
# 36       1600.0  control      andere              1991.0    manuell     75.0
# 41       7500.0  control   limousine              2002.0  automatik    306.0
# ...         ...      ...         ...                 ...        ...      ...
# 125148   4200.0     test   limousine              2003.0    manuell    143.0
# 125154  31499.0     test         NaN              2018.0    manuell    300.0
# 125159      0.0  control       kombi              1996.0        NaN      0.0
# 125170      0.0     test         NaN              1980.0        NaN      0.0
# 125192      NaN      NaN         NaN                 NaN        NaN      NaN
#
#            model  kilometer  monthOfRegistration fuelType          brand  \
# 9           golf   150000.0                  0.0      NaN     volkswagen
# 13        passat   150000.0                  2.0      NaN     volkswagen
# 26            c4   125000.0                  4.0      NaN        citroen
# 36        kadett    70000.0                  0.0      NaN           opel
# 41      e_klasse   150000.0                  4.0      NaN  mercedes_benz
# ...          ...        ...                  ...      ...            ...
# 125148       3er   150000.0                  5.0      NaN            bmw
# 125154      golf    20000.0                  3.0      NaN     volkswagen
# 125159       NaN     5000.0                  0.0      NaN     volkswagen
# 125170    andere    60000.0                  0.0      NaN      chevrolet
# 125192       NaN        NaN                  NaN      NaN            NaN
#
#        notRepairedDamage
# 9                    NaN
# 13                  nein
# 26                  nein
# 36                   NaN
# 41                   NaN
# ...                  ...
# 125148              nein
# 125154              nein
# 125159               NaN
# 125170              nein
# 125192               NaN
#
# [11278 rows x 12 columns]

# %%
base['fuelType'].value_counts()
# Out:
# fuelType
# benzin     75493
# diesel     36233
# lpg         1778
# cng          198
# hybrid        98
# andere        71
# elektro       44
# Name: count, dtype: int64

# %%
base.loc[pd.isnull(base['notRepairedDamage'])]
# Out:
#           price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480.0     test         NaN              1993.0    manuell      0.0
# 2        9800.0     test         suv              2004.0  automatik    163.0
# 8       14500.0  control         bus              2014.0    manuell    125.0
# 9         999.0     test  kleinwagen              1998.0    manuell    101.0
# 12        999.0  control       kombi              1995.0    manuell    115.0
# ...         ...      ...         ...                 ...        ...      ...
# 125174   9500.0     test         suv              1972.0    manuell     75.0
# 125183    900.0  control       coupe              1998.0    manuell    102.0
# 125184    600.0     test       kombi              2002.0    manuell    101.0
# 125185   6200.0     test       coupe              2004.0  automatik    150.0
# 125192      NaN      NaN         NaN                 NaN        NaN      NaN
#
#          model  kilometer  monthOfRegistration fuelType       brand  \
# 0         golf   150000.0                  0.0   benzin  volkswagen
# 2        grand   125000.0                  8.0   diesel        jeep
# 8        c_max    30000.0                  8.0   benzin        ford
# 9         golf   150000.0                  0.0      NaN  volkswagen
# 12      passat   150000.0                 11.0   benzin  volkswagen
# ...        ...        ...                  ...      ...         ...
# 125174  andere    80000.0                  5.0   benzin        jeep
# 125183     3er   150000.0                  6.0   benzin         bmw
# 125184  vectra   150000.0                  4.0   diesel        opel
# 125185     3er   150000.0                 10.0   diesel         bmw
# 125192     NaN        NaN                  NaN      NaN         NaN
#
#        notRepairedDamage
# 0                    NaN
# 2                    NaN
# 8                    NaN
# 9                    NaN
# 12                   NaN
# ...                  ...
# 125174               NaN
# 125183               NaN
# 125184               NaN
# 125185               NaN
# 125192               NaN
#
# [24270 rows x 12 columns]

# %%
base['notRepairedDamage'].value_counts()
# Out:
# notRepairedDamage
# nein    88684
# ja      12239
# Name: count, dtype: int64

# %%
valores = {'vehicleType': 'limousine',
           'gearbox': 'manuell',
           'model': 'golf',
           'fuelType': 'benzin',
           'notRepairedDamage': 'nein'}

# %%
base = base.fillna(value = valores)

# %%
base
# Out:
#           price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480.0     test   limousine              1993.0    manuell      0.0
# 1       18300.0     test       coupe              2011.0    manuell    190.0
# 2        9800.0     test         suv              2004.0  automatik    163.0
# 3        1500.0     test  kleinwagen              2001.0    manuell     75.0
# 4        3600.0     test  kleinwagen              2008.0    manuell     69.0
# ...         ...      ...         ...                 ...        ...      ...
# 125188   3200.0     test  kleinwagen              2003.0    manuell     75.0
# 125189   2990.0  control       kombi              2008.0    manuell      0.0
# 125190   9250.0  control       kombi              2008.0    manuell    170.0
# 125191    650.0     test       kombi              1996.0    manuell    116.0
# 125192      NaN      NaN   limousine                 NaN    manuell      NaN
#
#           model  kilometer  monthOfRegistration fuelType       brand  \
# 0          golf   150000.0                  0.0   benzin  volkswagen
# 1          golf   125000.0                  5.0   diesel        audi
# 2         grand   125000.0                  8.0   diesel        jeep
# 3          golf   150000.0                  6.0   benzin  volkswagen
# 4         fabia    90000.0                  7.0   diesel       skoda
# ...         ...        ...                  ...      ...         ...
# 125188    ibiza   150000.0                  8.0   benzin        seat
# 125189  octavia   150000.0                 10.0   diesel       skoda
# 125190   passat   150000.0                  5.0   diesel  volkswagen
# 125191   passat   150000.0                 12.0   benzin  volkswagen
# 125192     golf        NaN                  NaN   benzin         NaN
#
#        notRepairedDamage
# 0                   nein
# 1                     ja
# 2                   nein
# 3                   nein
# 4                   nein
# ...                  ...
# 125188              nein
# 125189              nein
# 125190              nein
# 125191              nein
# 125192              nein
#
# [125193 rows x 12 columns]

# %%
base.isnull().sum()
# Out:
# price                  1
# abtest                 1
# vehicleType            0
# yearOfRegistration     1
# gearbox                0
# powerPS                1
# model                  0
# kilometer              1
# monthOfRegistration    1
# fuelType               0
# brand                  1
# notRepairedDamage      0
# dtype: int64

# %%
base.columns
# Out:
# Index(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType',
#        'brand', 'notRepairedDamage'],
#       dtype='object')

# %%
X = base.iloc[:, 1:12].values # Atributos previsores
X
# Out:
# array([['test', 'limousine', 1993.0, ..., 'benzin', 'volkswagen', 'nein'],
#        ['test', 'coupe', 2011.0, ..., 'diesel', 'audi', 'ja'],
#        ['test', 'suv', 2004.0, ..., 'diesel', 'jeep', 'nein'],
#        ...,
#        ['control', 'kombi', 2008.0, ..., 'diesel', 'volkswagen', 'nein'],
#        ['test', 'kombi', 1996.0, ..., 'benzin', 'volkswagen', 'nein'],
#        [nan, 'limousine', nan, ..., 'benzin', nan, 'nein']], dtype=object)

# %%
y = base.iloc[:, 0].values # Atributo classe
y
# Out:
# array([  480., 18300.,  9800., ...,  9250.,   650.,    nan])

# %%
base['brand'].value_counts()
# Out:
# brand
# volkswagen        26742
# bmw               13597
# opel              13434
# mercedes_benz     11894
# audi              10939
# ford               8683
# renault            6091
# peugeot            3735
# fiat               3216
# seat               2433
# mazda              2022
# skoda              1916
# citroen            1786
# smart              1748
# nissan             1683
# toyota             1541
# sonstige_autos     1344
# hyundai            1239
# mini               1164
# volvo              1111
# mitsubishi         1007
# honda               936
# kia                 884
# suzuki              809
# alfa_romeo          759
# porsche             756
# chevrolet           635
# chrysler            503
# dacia               308
# land_rover          281
# daihatsu            280
# subaru              274
# jeep                271
# jaguar              222
# trabant             200
# daewoo              185
# lancia              177
# saab                167
# rover               139
# lada                 81
# Name: count, dtype: int64

# %%
base.columns
# Out:
# Index(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType',
#        'brand', 'notRepairedDamage'],
#       dtype='object')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

onehotencoder = ColumnTransformer(transformers=[("OneHot", OneHotEncoder(),
                                                 [0, 1, 3, 5, 8, 9, 10] # Índices das colunas categóricas
                                                 )],
                                  remainder='passthrough' # Mantém as colunas que não foram transformadas
                                  )

# %%
X = onehotencoder.fit_transform(X).toarray()
X
# Out:
# array([[0.00e+00, 1.00e+00, 0.00e+00, ..., 0.00e+00, 1.50e+05, 0.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.90e+02, 1.25e+05, 5.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.63e+02, 1.25e+05, 8.00e+00],
#        ...,
#        [1.00e+00, 0.00e+00, 0.00e+00, ..., 1.70e+02, 1.50e+05, 5.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.16e+02, 1.50e+05, 1.20e+01],
#        [0.00e+00, 0.00e+00, 1.00e+00, ...,      nan,      nan,      nan]])

# %%
base.shape
# Out:
# (125193, 12)

# %%
X.shape
# Out:
# (125193, 316)

# %%
(316 + 1) / 2
# Out:
# 158.5

# %%
regressor = Sequential([
    tf.keras.layers.InputLayer(shape = (316,)), # 316 colunas
    tf.keras.layers.Dense(units = 158, activation = 'relu'), # 316 + 1 / 2 = 158
    tf.keras.layers.Dense(units = 158, activation = 'relu'),
    tf.keras.layers.Dense(units = 1, activation = 'linear')
])

# %%
regressor.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 158)            │        50,086 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 158)            │        25,122 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           159 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,367 (294.40 KB)
#  Trainable params: 75,367 (294.40 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
12000 - 13000, 11500 - 10000
(abs(12000 - 13000) + abs(11500 - 10000)) / 2
# Out:
# 1250.0

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(X, y, batch_size = 300, epochs = 100)
# Out:
# Epoch 1/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: nan
# Epoch 2/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 3/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 4/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: nan
# Epoch 5/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 6/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 7/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 8/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 9/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: nan
# Epoch 10/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 11/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 12/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 13/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 14/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: nan
# Epoch 15/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: nan
# Epoch 16/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 17/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 18/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 19/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: nan
# Epoch 20/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: nan
# Epoch 21/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 22/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 23/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 24/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: nan
# Epoch 25/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: nan
# Epoch 26/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 27/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 28/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 29/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: nan
# Epoch 30/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 31/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 32/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 33/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: nan
# Epoch 34/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: nan
# Epoch 35/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: nan
# Epoch 36/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 37/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: nan
# Epoch 38/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: nan
# Epoch 39/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 40/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 41/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 42/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: nan
# Epoch 43/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: nan
# Epoch 44/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 45/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 46/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: nan
# Epoch 47/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 48/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: nan
# Epoch 49/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 50/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: nan
# Epoch 51/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: nan
# Epoch 52/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 53/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 54/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: nan
# Epoch 55/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: nan
# Epoch 56/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: nan
# Epoch 57/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 58/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 59/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 60/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 61/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 62/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 63/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: nan
# Epoch 64/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 65/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 66/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 67/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 68/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 69/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 70/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 71/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: nan
# Epoch 72/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 73/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 74/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 75/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 76/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 77/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 78/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: nan
# Epoch 79/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: nan
# Epoch 80/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 81/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 82/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 83/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 84/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: nan
# Epoch 85/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 86/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 87/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 88/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 89/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: nan
# Epoch 90/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 91/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 92/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 93/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan
# Epoch 94/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: nan
# Epoch 95/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 96/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 97/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 98/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: nan
# Epoch 99/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: nan
# Epoch 100/100
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: nan

# %%
X.shape
# Out:
# (125193, 316)

# %%
previsoes = regressor.predict(X) # Utilizando os dados para prever
# Out:
# 3913/3913 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step

# %%
previsoes
# Out:
# array([[5764.7656],
#        [4824.4526],
#        [4823.0674],
#        ...,
#        [5770.2227],
#        [5767.3726],
#        [      nan]], dtype=float32)

# %%
y
# Out:
# array([  480., 18300.,  9800., ...,  9250.,   650.,    nan])

# %%
y.mean()
# Out:
# np.float64(nan)

# %%
previsoes.mean()
# Out:
# np.float32(nan)
