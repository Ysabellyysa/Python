# %% [markdown]
# <a href="https://colab.research.google.com/github/Ysabellyysa/Python/blob/main/Other_Important_Operations_Aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %% [markdown]
# ### Multiplicação de matrizes
#
# ### Se A e B são duas matrizes, podemos multiplicá-las apenas se tiverem as dimensões A (n x m) e B (m x z), o que resulta em uma matriz de dimensões C (n x z).

# %%
x = torch.tensor([[1,2,3,4],[5,6,7,8]]) # shape = (2,4)
y = torch.tensor([[1,2,3],
                  [2,3,4],
                  [4,5,6],
                  [7,8,9]]) #shape = (4,3)

# %%
#essa função multiplica os dois tensores
torch.matmul(x,y)#shape = (2,3)
# Out:
# tensor([[ 45,  55,  65],
#         [101, 127, 153]])

# %% [markdown]
# ### Concatenação

# %%
x = torch.randn(1,4,5)
z = torch.cat([x,x], axis=1)
print('concatenated axis 1:', x.shape, z.shape)
# Out:
# concatenated axis 1: torch.Size([1, 4, 5]) torch.Size([1, 8, 5])

# %% [markdown]
# ### Permutação

# %%
x = torch.randn(3,20,10)
z = x.permute(2,0,1)
print('Permute dimensions:', x.shape, z.shape)
# Out:
# Permute dimensions: torch.Size([3, 20, 10]) torch.Size([10, 3, 20])

# %% [markdown]
# ### magine o tensor acima como uma imagem colorida (com 3 canais) e dimensões de altura e largura iguais a (20, 10). Eixo 0: canais; Eixo 1: altura; Eixo 2: largura. Ao realizar uma permutação (digamos, para (2, 0, 1)), trocamos os eixos na ordem definida pela operação de permutação. Assim, as dimensões passam a ser (10, 3, 20).
