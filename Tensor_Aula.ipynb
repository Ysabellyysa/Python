# %% [markdown]
# <a href="https://colab.research.google.com/github/Ysabellyysa/Python/blob/main/Tensor_Aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %% [markdown]
# ### Como criar um objeto tensor

# %% [markdown]
# ### 1-D array

# %%
#Criação de dois tensores usando a biblioteca Pytorch
sample = torch.tensor([10,11])
sample.shape
# Out:
# torch.Size([2])

# %%
#Assim que o parêntese terminar, leve os números para a parte inferior.
x = torch.tensor([[10,11], [1,2]]) #criação de um terceiro tensor com nome de X, com duas linhas e duas colunas
x.shape
# Out:
# torch.Size([2, 2])

# %%
#criando outro tensor chamado y com duas listas e uma coluna
y = torch.tensor([[10], [11]])
y.shape
# Out:
# torch.Size([2, 1])

# %% [markdown]
# ### O código abaixo ajudaria você a visualizar melhor um tensor 3D, onde "a" é um tensor tridimensional.

# %%
from plotly.graph_objs.layout import title
import torch
import plotly.graph_objs as go
import plotly.offline as pyo

#criando tensor de 3-dimensional
a = torch.tensor([[[1,2], [3,4]], [[5,6], [7, 8]]]) # tensor com duas listas, cada uma contendo uma matriz 2x2

#crie uma lista de todos os valores x, y e z no tensor
x_vals = []
y_vals = []
z_vals = []
#percorre as dimensões do tensor, adicionando os valores de cada índice á lista correspondente
for i in range(a.shape[0]):
  for j in range(a.shape[1]):
    for k in range(a.shape[2]):
      x_vals.append(i)
      y_vals.append(j)
      z_vals.append(k)

#crie um gráfico de dispersão 3D com Plotly
trace = go.Scatter3d(
    x=x_vals,
    y=y_vals,
    z=z_vals,
    mode = 'markers',
    marker=dict(
        size=5,
        color=a.flatten(),
        colorscale='viridis',
        opacity=0.8
    )
)

#crie o esboço do enredo
layout = go.Layout(
    margin=dict(l=0, r=0, b=0, t=0),
    scene=dict(
        xaxis=dict(title='Dimension 1'),
        yaxis=dict(title='Dimension 2'),
        zaxis=dict(title='Dimension 3'),
    )
)

#Combine o traço e o layout em uma figura e exiba-a
fig = go.Figure(data=[trace], layout=layout)
pyo.plot(fig, filename='tensor.html')
# Out:
# 'tensor.html'
